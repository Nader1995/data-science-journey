# %% [markdown]
# # My first notebook
#
# This notebook is part of my Data Science journey

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
x = 5
y = 10

print("The sum of x and y is:", x + y)
# Out:
# The sum of x and y is: 15
